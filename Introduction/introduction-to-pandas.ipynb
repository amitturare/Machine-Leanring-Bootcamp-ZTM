# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd

# %%
# 2 main data types
series = pd.Series(['BMW', 'Toyota', 'Honda'])

# %%
series
# series = 1-dimensional
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colors = pd.Series(['Red', 'Blue', 'White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
 # Dataframe = 2-dimensional
car_data = pd.DataFrame({'Car Name':series, 'Color': colors})
car_data
# Out:
#   Car Name  Color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data 
car_sales = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv')
# axis=1; columns
# axis=0; rows
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting Dataframes
car_sales.to_csv('exported-car-sales.csv', index=False)

# %%
pd.read_csv('exported-car-sales.csv')
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attributes doesn't require parenthesis at the end, Functions like 'to_csv' require parenthesis
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales.sum(numeric_only=True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## VIEWING and SELECTING DATA

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc and iloc
animals = pd.Series(['Cat', 'Dog', 'Bird', 'Panda', 'Snake'], index=[0, 3, 9, 8, 3])
animals
# Out:
# 0      Cat
# 3      Dog
# 9     Bird
# 8    Panda
# 3    Snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'Bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     Cat
# 3     Dog
# 9    Bird
# dtype: object

# %%
car_sales.loc[3:]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(4) # = car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
print(car_sales['Odometer (KM)']>100000)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Odometer (KM), dtype: bool

# %%
# Comparing two columns
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
type(car_sales['Odometer (KM)'].plot())
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3396/2458289569.py in <module>
# ----> 1 dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)
#
# NameError: name 'dataframe' is not defined

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]', '').astype(float)
# Out:
# C:\Users\amitt\AppData\Local\Temp/ipykernel_267000/953620215.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]', '').astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulation Data

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isnull()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
car_sales_missing.Odometer.fillna(car_sales_missing.Odometer.mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)
# inplace is set to true to avoid reassingments!!!

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# to remove the nan rows
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# inplace is important to avoid reassingment and to make change to the first and main variable
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called as seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales.Seats.fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
# Making column from a Python list 
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]

car_sales['Fuel per 100KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             9.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.7
# 5  Toyota  Green          99213      4   4500.0    5.0             4.7
# 6   Honda   Blue          45698      4   7500.0    5.0             7.6
# 7   Honda   Blue          54738      4   7000.0    5.0             8.7
# 8  Toyota  White          60000      4   6250.0    5.0             3.0
# 9  Nissan  White          31600      4   9700.0    5.0             4.5

# %%
# create a column using another column 
car_sales['Total fuel used (L)'] = (car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM'])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             9.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.7
# 5  Toyota  Green          99213      4   4500.0    5.0             4.7
# 6   Honda   Blue          45698      4   7500.0    5.0             7.6
# 7   Honda   Blue          54738      4   7000.0    5.0             8.7
# 8  Toyota  White          60000      4   6250.0    5.0             3.0
# 9  Nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# 2         1627.450             1627.450
# ...

# %%
# Create a colum from a single value
car_sales['Number of wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             9.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.7
# 5  Toyota  Green          99213      4   4500.0    5.0             4.7
# 6   Honda   Blue          45698      4   7500.0    5.0             7.6
# 7   Honda   Blue          54738      4   7000.0    5.0             8.7
# 8  Toyota  White          60000      4   6250.0    5.0             3.0
# 9  Nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         8086.708             8086.708                 4
# ...

# %%
car_sales['Passed road saftey'] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used        float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             9.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.7
# 5  Toyota  Green          99213      4   4500.0    5.0             4.7
# 6   Honda   Blue          45698      4   7500.0    5.0             7.6
# 7   Honda   Blue          54738      4   7000.0    5.0             8.7
# 8  Toyota  White          60000      4   6250.0    5.0             3.0
# 9  Nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed road saftey
# 0        11253.225            11253.225                 4                True
# ...

# %%
car_sales.drop('Total fuel used', axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.2
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             9.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.7
# 5  Toyota  Green          99213      4   4500.0    5.0             4.7
# 6   Honda   Blue          45698      4   7500.0    5.0             7.6
# 7   Honda   Blue          54738      4   7000.0    5.0             8.7
# 8  Toyota  White          60000      4   6250.0    5.0             3.0
# 9  Nissan  White          31600      4   9700.0    5.0             4.5
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales['Total fuel used (L)'].plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 4  Nissan  White         213095      4   $3,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 7   Honda   Blue          54738      4   $7,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 1   Honda    Red          87899      4   $5,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# only select 20 % of the data 
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 1   Honda    Red          87899      4   $5,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_shuffled.reset_index(inplace=True, drop=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1  Nissan  White         213095      4   $3,500.00
# 2   Honda   Blue          54738      4   $7,000.00
# 3   Honda   Blue          45698      4   $7,500.00
# 4   Honda    Red          87899      4   $5,000.00
# 5     BMW  Black          11179      5  $22,000.00
# 6  Toyota   Blue          32549      3   $7,000.00
# 7  Toyota  Green          99213      4   $4,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White   36631.591797      4   $4,000.00
# 1   Honda    Red   21459.716797      4   $5,000.00
# 2  Toyota   Blue    7946.533203      3   $7,000.00
# 3     BMW  Black    2729.248047      5  $22,000.00
# 4  Nissan  White   52025.146484      4   $3,500.00
# 5  Toyota  Green   24221.923828      4   $4,500.00
# 6   Honda   Blue   11156.738281      4   $7,500.00
# 7   Honda   Blue   13363.769531      4   $7,000.00
# 8  Toyota  White   14648.437500      4   $6,250.00
# 9  Nissan  White    7714.843750      4   $9,700.00

# %%
# Try it, run your code
# Search for it
# Try again 
# Ask
